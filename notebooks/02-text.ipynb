# %%
import sys
sys.path.append('..')

# %%
import pandas as pd

from lib.data import load_extracted_samples
from lib.text import try_extract_from_text

# %%
samples = load_extracted_samples()

for sample in samples:
    sample = sample.update(try_extract_from_text(sample["text"]))

# %%
df = pd.json_normalize(samples)
df["has_text"] = df["text"].apply(lambda x: len(x) > 0)
# df

# %%
# all samples that have text should have total
df[df["has_text"] & df["total"].isna()]
# Out:
# Empty DataFrame
# Columns: [filename, size, pages, text, images, invoice, total, has_text]
# Index: []

# %%
# all samples that have text should have invoice
df[df["has_text"] & df["invoice"].isna()]
# Out:
# Empty DataFrame
# Columns: [filename, size, pages, text, images, invoice, total, has_text]
# Index: []

# %%
# invoice string should not be too short
df[df["invoice"].str.len() < 6]
# Out:
# Empty DataFrame
# Columns: [filename, size, pages, text, images, invoice, total, has_text]
# Index: []

# %%
# invoice string should be alphanumeric
df[df["has_text"] & ~(df["invoice"].isna() | df["invoice"].str.isalnum())]
# Out:
# Empty DataFrame
# Columns: [filename, size, pages, text, images, invoice, total, has_text]
# Index: []

# %%
# complete data
df[df["has_text"] & df["total"].notna() & df["invoice"].notna()]
# Out:
#                 filename   size  pages  \
# 0          102819958.pdf  54567      2
# 1          105002622.pdf  46078      2
# 5          109849880.pdf  46680      2
# 8          113028839.pdf  46698      2
# 21         126722170.pdf  46137      2
# 23         128362530.pdf  46815      2
# 28         136782590.pdf  53557      2
# 31         139537191.pdf  53852      2
# 33         145774620.pdf  54591      2
# 37          15071103.pdf  46459      2
# 54         187085275.pdf  46368      2
# 59         191433200.pdf  54242      2
# 60         191735158.pdf  47205      2
# 61         192415484.pdf  46448      2
# 65         196629123.pdf  46736      2
# 69         201573028.pdf  47126      2
# 72   2021-01-04_4242.pdf  47274      2
# 76    2021-01-08_637.pdf  46488      2
# 78   2021-01-09_7328.pdf  53741      2
# 80   2021-01-10_3627.pdf  46843      2
# 83   2021-01-12_1623.pdf  47407      2
# 88   2021-01-14_2076.pdf  55053      2
# 93   2021-01-15_6976.pdf  46609      2
# 97   2021-01-16_8405.pdf  47469      2
# 98   2021-01-17_3813.pdf  54298      2
# 100  2021-01-18_8032.pdf  53583      2
# 102  2021-01-20_1816.pdf  52829      2
# 103  2021-01-20_3014.pdf  47179      2
# 105  2021-01-21_1021.pdf  47661      2
#
#                                                   text  \
# 0    Invoice num.: 102819958\nInvoice issued: Oct 9...
# 1    Inv.: 105002622\n: Nov 4, 2022\nCollins, Orteg...
# 5    : 109849880\nRecord date: Mar 28, 2023\nHuber ...
# 8    Issuance date: Feb 9, 2021\nNum: 113028839\nCa...
# 21   Date of Exposure: Dec 20, 2021\nLocator #: 126...
# 23   : Apr 30, 2023\nInvoice num.: 128362530\nMarti...
# 28   Invoice Locator: 136782590\nPayment Due: Feb 2...
# 31   Invoice: 139537191\nDue on: May 17, 2023\nHill...
# 33   Invoice num.: 145774620\nInvoice Date: Aug 20,...
# 37   Inv#: 15071103\nPayment Due: Sep 5, 2022\nGrah...
# 54   Invoice: 187085275\nIssuance date: Jan 28, 202...
# 59   Invoice Locator: 191433200\nInvoice Date: May ...
# 60   : Jun 12, 2022\nInv.: 191735158\nBrown LLC - M...
# 61   Due Date: Mar 11, 2021\nNum: 192415484\nVargas...
# 65   Record date: Aug 3, 2021\nInvoice: 196629123\n...
# 69   Invoice #: 201573028\nPayment Due: Jun 3, 2022...
# 72   Invoice Date: Jan 4, 2021\nInv#: J76634652\nGr...
# 76   : 771105327\nInvoice issued: Jan 8, 2021\nSmit...
# 78   Payment Due: Jan 9, 2021\nLocator #: R63237145...
# 80   : Y69980783\nRecord date: Jan 10, 2021\nBenson...
# 83   : A95998530\nDue on: Jan 12, 2021\nThomas, Mor...
# 88   Invoice issued: Jan 14, 2021\nNum: 575580040\n...
# 93   Payment Due: Jan 15, 2021\nInv#: T07681678\nSa...
# 97   Date of Exposure: Jan 16, 2021\nLocator #: M28...
# 98   : K78726156\n: Jan 17, 2021\nJenkins-Baker - S...
# 100  : Jan 18, 2021\n: 514599571\nValentine, Garcia...
# 102  Inv.: 435414097\nDue Date: Jan 20, 2021\nMejia...
# 103  Invoice #: 679053956\nRecord date: Jan 20, 202...
# 105  Record date: Jan 21, 2021\n: D44139084\nAdams-...
#
#                                                 images    invoice     total  \
# 0                                                   []  102819958  24585.89
# 1                                                   []  105002622  27216.52
# 5                                                   []  109849880   9111.77
# 8                                                   []  113028839  54148.19
# 21                                                  []  126722170  15948.63
# 23                                                  []  128362530  25484.03
# 28                                                  []  136782590  13325.56
# 31                                                  []  139537191  18641.91
# 33                                                  []  145774620  19607.56
# 37                                                  []   15071103  32259.51
# 54                                                  []  187085275  25385.16
# 59                                                  []  191433200  29240.95
# 60                                                  []  191735158  29010.85
# 61                                                  []  192415484  59401.30
# 65                                                  []  196629123  23694.30
# 69                                                  []  201573028  28612.20
# 72                                                  []  J76634652  23114.12
# 76                                                  []  771105327  24373.67
# 78                                                  []  R63237145  26178.63
# 80                                                  []  Y69980783  21683.19
# 83                                                  []  A95998530  31754.27
# 88                                                  []  575580040  29784.81
# 93                                                  []  T07681678  19727.92
# 97                                                  []  M28123796  15117.86
# 98                                                  []  K78726156  38784.33
# 100                                                 []  514599571  15527.03
# 102  [/mnt/c/Users/mlomb/Desktop/ParaiSUR/data-extr...  435414097  43896.08
# 103                                                 []  679053956  16108.62
# 105                                                 []  D44139084  36284.26
#
#      has_text
# 0        True
# 1        True
# 5        True
# 8        True
# 21       True
# 23       True
# 28       True
# 31       True
# 33       True
# 37       True
# 54       True
# 59       True
# 60       True
# 61       True
# 65       True
# 69       True
# 72       True
# 76       True
# 78       True
# 80       True
# 83       True
# 88       True
# 93       True
# 97       True
# 98       True
# 100      True
# 102      True
# 103      True
# 105      True
